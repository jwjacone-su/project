# %%
import pandas as pd
import folium
import plotly.graph_objects as go

# %%
candidates= pd.read_csv('Pres_candidates_info.csv')
candidates.head(27)
# Out:
#       Twitter Handle                 Name Sex  Birthdate Announcement Party  \
# 0       @sethmoulton         Seth Moulton   M  24-Oct-78    22-Apr-19     D
# 1     @SenGillibrand   Kirsten Gillibrand   F   9-Dec-66    15-Jan-19     D
# 2      @Hickenlooper    John Hickenlooper   M   7-Feb-52     4-Mar-19     D
# 3       @JohnDelaney         John Delaney   M  16-Apr-63    10-Aug-17     D
# 4      @KamalaHarris        Kamala Harris   F  20-Oct-64    21-Jan-19     D
# 5          @JoeBiden            Joe Biden   M  20-Nov-42    25-Apr-19     D
# 6           @TimRyan             Tim Ryan   M  16-Jul-73     4-Apr-19     D
# 7           @ewarren     Elizabeth Warren   F  22-Jun-49     9-Feb-19     D
# 8   @realDonaldTrump         Donald Trump   M  14-Jun-46          NaN     R
# 9      @JulianCastro        Julian Castro   M  16-Sep-74    12-Jan-19     D
# 10     @BilldeBlasio       Bill de Blasio   M   8-May-61    16-May-19     D
# 11    @marwilliamson  Marianne Williamson   F   8-Jul-52    28-Jan-19     D
# 12    @BernieSanders       Bernie Sanders   M   8-Sep-41    19-Feb-19     D
# 13       @CoryBooker          Cory Booker   M  27-Apr-69     1-Feb-19     D
# 14       @mike_pence           Mike Pence   M   7-Jun-59          NaN     R
# 15       @AndrewYang          Andrew Yang   M  13-Jan-75     6-Nov-17     D
# 16     @ericswalwell        Eric Swalwell   M  16-Nov-80     8-Apr-19     D
# 17       @MikeGravel          Mike Gravel   M  13-May-30     2-Apr-19     D
# 18        @JayInslee           Jay Inslee   M   9-Feb-51     1-Mar-19     D
# 19  @GovernorBullock        Steve Bullock   M  11-Apr-66    14-May-19     D
# 20    @MichaelBennet       Michael Bennet   M  28-Nov-64     2-May-19     D
# 21      @BetoORourke        Beto O'Rourke   M  26-Sep-72    14-Mar-19     D
# 22    @PeteButtigieg       Pete Buttigieg   M  19-Jan-82    23-Jan-19     D
# 23     @TulsiGabbard        Tulsi Gabbard   F  12-Apr-81    11-Jan-19     D
# 24     @amyklobuchar        Amy Klobuchar   F  25-May-60    10-Feb-19     D
# 25      @WayneMessam         Wayne Messam   M   7-Jun-74    13-Mar-19     D
# 26      @GovBillWeld            Bill Weld   M  31-Jul-45    15-Apr-19     R
#
#    City of Residence State of Residence  No. of Children
# 0              Salem                 MA                1
# 1           New York                 NY                2
# 2             Denver                 CO                1
# 3        Chevy Chase                 MD                4
# 4      San Francisco                 CA                0
# 5         Wilmington                 DE                4
# 6            Howland                 OH                1
# 7          Cambridge                 MA                2
# 8           New York                 NY                5
# 9        San Antonio                 TX                2
# 10          New York                 NY                2
# 11          Houston                  TX                1
# 12           Vermont                 VT                4
# 13            Newark                 NJ                0
# 14          Columbus                 IN                3
# 15          New York                 NY                2
# 16        Pleasanton                 CA                2
# 17        Burlingame                 CA                2
# 18           Olympia                 WA                3
# 19            Helena                 MT                3
# 20           Denver                  CO                3
# 21           El Paso                 TX                3
# 22        South Bend                 IN                0
# 23          Honoluly                 HI                0
# 24       Minneapolis                 MN                1
# 25           Miramar                 FL                3
# 26          New York                 NY                5

# %%
# part 3

candidates= pd.read_csv('Pres_candidates_info.csv')
from IPython.display import Image

candidate= input('Enter name of Presidential Candidate: ').lower()
if candidate == 'joe biden':
    display(Image("pics/JoeBiden.jpg"))
    print(candidates.loc[5,:])
elif candidate == 'seth moulton':
    display(Image("pics/sethmoulton.jpg"))
    print(candidates.loc[0,:])
elif candidate == 'kirsten gillibrand':
    display(Image("pics/SenGillibrand.jpg"))
    print(candidates.loc[1,:])
elif candidate == 'john hickenlooper':
    print(candidates.loc[2,:])
elif candidate == 'john delaney':
    display(Image("pics/JohnDelaney.jpg"))
    print(candidates.loc[3,:])
elif candidate == 'kamala harris':
    display(Image("pics/KamalaHarris.jpg"))
    print(candidates.loc[4,:])
elif candidate == 'tim ryan':
    display(Image("pics/TimRyan.png"))
    print(candidates.loc[6,:])
elif candidate == 'elizabeth warren':
    display(Image("pics/ewarren.png"))
    print(candidates.loc[7,:])
elif candidate == 'donald trump':
    display(Image("pics/realDonaldTrump.jpg"))
    print(candidates.loc[8,:])
elif candidate == 'julian castro':
    display(Image("pics/JulianCastro.jpg"))
    print(candidates.loc[9,:])
elif candidate == 'bill de blasio':
    display(Image("pics/BilldeBlasio.png"))
    print(candidates.loc[10,:])
elif candidate == 'marianne williamson':
    display(Image("pics/marwilliamson.jpg"))
    print(candidates.loc[11,:])
elif candidate == 'bernie sanders':
    display(Image("pics/BernieSanders.jpg"))
    print(candidates.loc[12,:])
elif candidate == 'cory booker':
    display(Image("pics/CoryBooker.jpg"))
    print(candidates.loc[13,:])
elif candidate == 'mike pence':
    display(Image("pics/mike_pence.jpg"))
    print(candidates.loc[14,:])
elif candidate == 'andrew yang':
    display(Image("pics/AndrewYang.jpg"))
    print(candidates.loc[15,:])
elif candidate == 'eric swalwell':
    display(Image("pics/ericswalwell.jpg"))
    print(candidates.loc[16,:])
elif candidate == 'mike gravel':
    display(Image("pics/MikeGravel.png"))
    print(candidates.loc[17,:])
elif candidate == 'jay inslee':
    display(Image("pics/JayInslee.jpg"))
    print(candidates.loc[18,:])
elif candidate == 'steve bullock':
    display(Image("pics/GovernorBullock.jpg"))
    print(candidates.loc[19,:])
elif candidate == 'michael bennet':
    display(Image("pics/MichaelBennet.jpg"))
    print(candidates.loc[20,:])
elif candidate == "beto o'rourke":
    display(Image("pics/BetoORourke.jpg"))
    print(candidates.loc[21,:])
elif candidate == 'pete buttigieg':
    display(Image("pics/PeteButtigieg.png"))
    print(candidates.loc[22,:])
elif candidate == 'tulsi gabbard':
    display(Image("pics/TulsiGabbard.jpg"))
    print(candidates.loc[23,:])
elif candidate == 'amy klobuchar':
    display(Image("pics/amyklobuchar.jpg"))
    print(candidates.loc[24,:])
elif candidate == 'wayne messam':
    display(Image("pics/WayneMessam.jpg"))
    print(candidates.loc[25,:])
elif candidate == 'bill weld':
    display(Image("pics/GovBillWeld.png"))
    print(candidates.loc[26,:])

    
          
else:
    print("That is not a candidate!")
# Out:
# Enter name of Presidential Candidate: kamala harris
# Twitter Handle        @KamalaHarris
# Name                  Kamala Harris
# Sex                               F
# Birthdate                 20-Oct-64
# Announcement              21-Jan-19
# Party                             D
# City of Residence     San Francisco
# State of Residence               CA
# No. of Children                   0
# Name: 4, dtype: object

# %%
def CandidateLookup(candidate):
    if candidate == 'joe biden':
        display(Image("pics/JoeBiden.jpg"))
        print(candidates.loc[5,:])
    elif candidate == 'seth moulton':
        display(Image("pics/sethmoulton.jpg"))
        print(candidates.loc[0,:])
    elif candidate == 'kirsten gillibrand':
        display(Image("pics/SenGillibrand.jpg"))
        print(candidates.loc[1,:])
    elif candidate == 'john hickenlooper':
        print(candidates.loc[2,:])
    elif candidate == 'john delaney':
        display(Image("pics/JohnDelaney.jpg"))
        print(candidates.loc[3,:])
    elif candidate == 'kamala harris':
        display(Image("pics/KamalaHarris.jpg"))
        print(candidates.loc[4,:])
    elif candidate == 'tim ryan':
        display(Image("pics/TimRyan.png"))
        print(candidates.loc[6,:])
    elif candidate == 'elizabeth warren':
        display(Image("pics/ewarren.png"))
        print(candidates.loc[7,:])
    elif candidate == 'donald trump':
        display(Image("pics/realDonaldTrump.jpg"))
        print(candidates.loc[8,:])
    elif candidate == 'julian castro':
        display(Image("pics/JulianCastro.jpg"))
        print(candidates.loc[9,:])
    elif candidate == 'bill de blasio':
        display(Image("pics/BilldeBlasio.png"))
        print(candidates.loc[10,:])
    elif candidate == 'marianne williamson':
        display(Image("pics/marwilliamson.jpg"))
        print(candidates.loc[11,:])
    elif candidate == 'bernie sanders':
        display(Image("pics/BernieSanders.jpg"))
        print(candidates.loc[12,:])
    elif candidate == 'cory booker':
        display(Image("pics/CoryBooker.jpg"))
        print(candidates.loc[13,:])
    elif candidate == 'mike pence':
        display(Image("pics/mike_pence.jpg"))
        print(candidates.loc[14,:])
    elif candidate == 'andrew yang':
        display(Image("pics/AndrewYang.jpg"))
        print(candidates.loc[15,:])
    elif candidate == 'eric swalwell':
        display(Image("pics/ericswalwell.jpg"))
        print(candidates.loc[16,:])
    elif candidate == 'mike gravel':
        display(Image("pics/MikeGravel.png"))
        print(candidates.loc[17,:])
    elif candidate == 'jay inslee':
        display(Image("pics/JayInslee.jpg"))
        print(candidates.loc[18,:])
    elif candidate == 'steve bullock':
        display(Image("pics/GovernorBullock.jpg"))
        print(candidates.loc[19,:])
    elif candidate == 'michael bennet':
        display(Image("pics/MichaelBennet.jpg"))
        print(candidates.loc[20,:])
    elif candidate == "beto o'rourke":
        display(Image("pics/BetoORourke.jpg"))
        print(candidates.loc[21,:])
    elif candidate == 'pete buttigieg':
        display(Image("pics/PeteButtigieg.png"))
        print(candidates.loc[22,:])
    elif candidate == 'tulsi gabbard':
        display(Image("pics/TulsiGabbard.jpg"))
        print(candidates.loc[23,:])
    elif candidate == 'amy klobuchar':
        display(Image("pics/amyklobuchar.jpg"))
        print(candidates.loc[24,:])
    elif candidate == 'wayne messam':
        display(Image("pics/WayneMessam.jpg"))
        print(candidates.loc[25,:])
    elif candidate == 'bill weld':
        display(Image("pics/GovBillWeld.png"))
        print(candidates.loc[26,:])
    else:
        print("That is not a candidate!")
    whitespace = ' '
    return whitespace

# %%
candidates= pd.read_csv('Pres_candidates_info.csv')
from IPython.display import Image
while True:
    candidate= input('Enter name of Presidential Candidate or type "quit" to stop: ').lower()
    if candidate == 'quit':
        print('Program Ending, Thank You!')
        break
    else:
        CandInfo = CandidateLookup(candidate)
        print(CandInfo)
# Out:
# Enter name of Presidential Candidate or type "quit" to stop: donald trump
# Twitter Handle        @realDonaldTrump
# Name                      Donald Trump
# Sex                                  M
# Birthdate                    14-Jun-46
# Announcement                       NaN
# Party                                R
# City of Residence             New York
# State of Residence                  NY
# No. of Children                      5
# Name: 8, dtype: object
#
# Enter name of Presidential Candidate or type "quit" to stop: stop
# That is not a candidate!
#
# Enter name of Presidential Candidate or type "quit" to stop: quit
# Program Ending, Thank You!
